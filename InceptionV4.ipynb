# %%
from tensorflow.keras.callbacks import EarlyStopping, History, ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from tensorflow.keras.layers import Conv2D, MaxPooling2D, concatenate, AveragePooling2D, BatchNormalization
from tensorflow.keras.layers import Input, Dense, Dropout, Activation, Flatten, GlobalAveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import optimizers, regularizers
from tensorflow.keras.models import Model, load_model
#from google.colab import drive
from datetime import datetime
import tensorflow as tf
import numpy as np
import warnings
import os

#drive.mount('/content/drive')
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
gpus = tf.config.list_physical_devices('GPU')
print("Los dispositivos encontrados son: ", gpus)
if gpus:
  try:
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "GPUs físicos,", len(logical_gpus), "GPUs lógicos")
  except RuntimeError as e:
    print(e)
print("----------------------------------------------------- \n")
# Out:
# Los dispositivos encontrados son:  [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 1 GPUs físicos, 1 GPUs lógicos
# -----------------------------------------------------

# %% [markdown]
# ## Generación del modelo

# %%
def input_section(input_shape):
    #First section of the input block
    conv_1 = Conv2D(filters = 32, kernel_size = (3, 3), strides = (2,2), activation = "relu")(input_shape)
    conv_2 = Conv2D(filters = 32, kernel_size = (3, 3), activation = "relu")(conv_1)
    conv_3 = Conv2D(filters = 64, kernel_size = (3, 3), padding = 'same', activation = "relu")(conv_2)
    conv_4 = Conv2D(filters = 96, kernel_size = (3, 3), strides = (2,2), activation = "relu")(conv_3)
    maxp_1 = MaxPooling2D(pool_size=(3, 3), strides= (2,2))(conv_3)  
    conc_1 = concatenate([maxp_1, conv_4], axis=3)
    
    #Second section of the input block
    conv_5 = Conv2D(filters = 64, kernel_size = (1, 1), padding = 'same',activation = "relu")(conc_1)
    conv_6 = Conv2D(filters = 64, kernel_size = (1, 1), padding = 'same', activation = "relu")(conc_1)
    conv_7 = Conv2D(filters = 96, kernel_size = (3, 3), activation = "relu")(conv_6)
    conv_8 = Conv2D(filters = 64, kernel_size = (7, 1), padding = 'same', activation = "relu")(conv_6)
    conv_9 = Conv2D(filters = 64, kernel_size = (1, 7), padding = 'same', activation = "relu")(conv_8)
    conv_10 = Conv2D(filters = 96, kernel_size = (3, 3), activation = "relu")(conv_9)
    conc_2 = concatenate([conv_7, conv_10], axis=3)
    
    #Third section of the input block
    maxp_2 = MaxPooling2D(pool_size=(3, 3),strides= (2,2))(conc_2)
    conv_11 = Conv2D(filters = 192, kernel_size = (3, 3),strides = (2,2), activation = "relu")(conc_2)
    conc_3 = concatenate([conv_11, maxp_2], axis=3)
    
    return conc_3

# %%
def inception_A_block(input_shape):
    conv_1 = Conv2D(filters = 64, kernel_size = (1, 1), padding = 'same', activation = "relu")(input_shape)
    conv_2 = Conv2D(filters = 64, kernel_size = (1, 1), padding = 'same', activation = "relu")(input_shape)
    conv_3 = Conv2D(filters = 96, kernel_size = (1, 1), padding = 'same', activation = "relu")(input_shape)
    avpo_1 = AveragePooling2D(pool_size=(1, 1), padding='same')(input_shape)
    
    conv_4 = Conv2D(filters = 96, kernel_size = (3, 3), padding = 'same', activation = "relu")(conv_1)
    conv_5 = Conv2D(filters = 96, kernel_size = (3, 3), padding = 'same', activation = "relu")(conv_2)
    conv_6 = Conv2D(filters = 96, kernel_size = (1, 1), padding = 'same', activation = "relu")(avpo_1)
    
    conv_7 = Conv2D(filters = 96, kernel_size = (3, 3), padding = 'same', activation = "relu")(conv_4)
    conc_1 = concatenate([conv_7,conv_5,conv_3,conv_6], axis = 3)
    
    return conc_1

# %%
def reduction_A_block(input_shape):
    conv_1 = Conv2D(filters = 192, kernel_size = (1, 1), padding = 'same', activation = "relu")(input_shape)
    conv_2 = Conv2D(filters = 224, kernel_size = (3, 3), padding = 'same', activation = "relu")(conv_1)
    conv_3 = Conv2D(filters = 384, kernel_size = (3, 3), strides = (2,2), activation = "relu")(input_shape)

    maxp_1 = MaxPooling2D(pool_size=(3, 3),strides= (2,2))(input_shape)
    conv_4 = Conv2D(filters = 256, kernel_size = (3, 3), strides = (2,2), activation = "relu")(conv_2)
    
    conc_1 = concatenate([conv_4,conv_3,maxp_1], axis = 3)
    
    return conc_1

# %%
def inception_B_block(input_shape):
    conv_1 = Conv2D(filters = 192, kernel_size = (1, 1), padding = 'same', activation = "relu")(input_shape)
    conv_2 = Conv2D(filters = 192, kernel_size = (1, 7), padding = 'same', activation = "relu")(conv_1)
    conv_3 = Conv2D(filters = 224, kernel_size = (7, 1), padding = 'same', activation = "relu")(conv_2)
    conv_4 = Conv2D(filters = 224, kernel_size = (1, 7), padding = 'same', activation = "relu")(conv_3)
    conv_5 = Conv2D(filters = 256, kernel_size = (7, 1), padding = 'same', activation = "relu")(conv_4)
    
    conv_6 = Conv2D(filters = 192, kernel_size = (1, 1), padding = 'same', activation = "relu")(input_shape)
    conv_7 = Conv2D(filters = 224, kernel_size = (1, 7), padding = 'same', activation = "relu")(conv_6)
    conv_8 = Conv2D(filters = 256, kernel_size = (1, 7), padding = 'same', activation = "relu")(conv_7)
    
    avpo_1 = AveragePooling2D(pool_size=(1, 1), padding='same')(input_shape)
    conv_9 = Conv2D(filters = 128, kernel_size = (1, 1), padding = 'same', activation = "relu")(avpo_1)
    
    conv_10 = Conv2D(filters = 384, kernel_size = (1, 1), padding = 'same', activation = "relu")(input_shape)
    
    conc_1 = concatenate([conv_5,conv_8,conv_9,conv_10], axis = 3)
    
    return conc_1

# %%
def reduction_B_block(input_shape):
    conv_1 = Conv2D(filters = 256, kernel_size = (1, 1), padding = 'same', activation = "relu")(input_shape)
    conv_2 = Conv2D(filters = 256, kernel_size = (1, 7), padding = 'same', activation = "relu")(conv_1)
    conv_3 = Conv2D(filters = 320, kernel_size = (7, 1), padding = 'same', activation = "relu")(conv_2)
    conv_4 = Conv2D(filters = 320, kernel_size = (3, 3), strides = (2, 2), activation = "relu")(conv_3)

    conv_5 = Conv2D(filters = 192, kernel_size = (1, 1), padding = 'same', activation = "relu")(input_shape)
    conv_6 = Conv2D(filters = 192, kernel_size = (3, 3), strides = (2, 2), activation = "relu")(conv_5)
    
    maxp_1 = MaxPooling2D(pool_size=(3, 3),strides= (2,2))(input_shape)

    
    conc_1 = concatenate([conv_4,conv_6,maxp_1], axis = 3)
    
    return conc_1

# %%
def inception_C_block(input_shape):
    conv_1 = Conv2D(filters = 384, kernel_size = (1, 1), padding = 'same', activation = "relu")(input_shape)
    conv_2 = Conv2D(filters = 448, kernel_size = (1, 3), padding = 'same', activation = "relu")(conv_1)
    conv_3 = Conv2D(filters = 512, kernel_size = (3, 1), padding = 'same', activation = "relu")(conv_2)
    conv_4 = Conv2D(filters = 256, kernel_size = (1, 3), padding = 'same', activation = "relu")(conv_3)
    conv_5 = Conv2D(filters = 256, kernel_size = (3, 1), padding = 'same', activation = "relu")(conv_3)
    
    conv_6 = Conv2D(filters = 384, kernel_size = (1, 1), padding = 'same', activation = "relu")(input_shape)
    conv_7 = Conv2D(filters = 256, kernel_size = (3, 1), padding = 'same', activation = "relu")(conv_6)
    conv_8 = Conv2D(filters = 256, kernel_size = (1, 3), padding = 'same', activation = "relu")(conv_6)
    
    avpo_1 = AveragePooling2D(pool_size=(1, 1), padding='same')(input_shape)
    conv_9 = Conv2D(filters = 256, kernel_size = (1, 1), padding = 'same', activation = "relu")(avpo_1)
    
    conv_10 = Conv2D(filters = 256, kernel_size = (1, 1), padding = 'same', activation = "relu")(input_shape)
    
    conc_1 = concatenate([conv_5,conv_4,conv_7,conv_8,conv_10,conv_9], axis = 3)
    
    return conc_1

# %%
tam = (300,300,3)
input_shape = Input(tam)

#Input inception block
inp = input_section(input_shape)

#Inception block-A (x4)
A1 = inception_A_block(inp)
A2 = inception_A_block(A1)
A3 = inception_A_block(A2)     
A4 = inception_A_block(A3)

#Reduction model A
AR = reduction_A_block(A4)
AR = BatchNormalization()(AR)
AR = MaxPooling2D(pool_size=(3, 3),strides= (2,2))(AR)

#Inception block-B (x7)
B1 = inception_B_block(AR)
B2 = inception_B_block(B1)
B3 = inception_B_block(B2)
B4 = inception_B_block(B3)
B5 = inception_B_block(B4)
B6 = inception_B_block(B5)
B7 = inception_B_block(B6)
    

#Reduction model B
BR = reduction_B_block(B7)
BR = BatchNormalization()(BR)
BR = MaxPooling2D(pool_size=(3, 3),strides= (2,2))(BR)

#Inception block-C (x3)
C1 = inception_C_block(BR)
C2 = inception_C_block(C1)
C3 = inception_C_block(C2)
C3 = BatchNormalization()(C3)

#Detection part

GLB = GlobalAveragePooling2D()(C3)

FC = Dense(2048)(GLB)
DP = Dropout(0.5)(FC)

y_pred = Dense(1, activation= "sigmoid")(DP)


#Creating model
model = Model(inputs = input_shape, outputs= y_pred)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 300, 300, 3) 0
# __________________________________________________________________________________________________
# conv2d_119 (Conv2D)             (None, 149, 149, 32) 896         input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_120 (Conv2D)             (None, 147, 147, 32) 9248        conv2d_119[0][0]
# __________________________________________________________________________________________________
# conv2d_121 (Conv2D)             (None, 147, 147, 64) 18496       conv2d_120[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 73, 73, 64)   0           conv2d_121[0][0]
# __________________________________________________________________________________________________
# conv2d_122 (Conv2D)             (None, 73, 73, 96)   55392       conv2d_121[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 73, 73, 160)  0           max_pooling2d_6[0][0]
#                                                                  conv2d_122[0][0]
# __________________________________________________________________________________________________
# conv2d_124 (Conv2D)             (None, 73, 73, 64)   10304       concatenate_16[0][0]
# __________________________________________________________________________________________________
# conv2d_126 (Conv2D)             (None, 73, 73, 64)   28736       conv2d_124[0][0]
# __________________________________________________________________________________________________
# conv2d_127 (Conv2D)             (None, 73, 73, 64)   28736       conv2d_126[0][0]
# __________________________________________________________________________________________________
# conv2d_125 (Conv2D)             (None, 71, 71, 96)   55392       conv2d_124[0][0]
# __________________________________________________________________________________________________
# conv2d_128 (Conv2D)             (None, 71, 71, 96)   55392       conv2d_127[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 71, 71, 192)  0           conv2d_125[0][0]
#                                                                  conv2d_128[0][0]
# __________________________________________________________________________________________________
# conv2d_129 (Conv2D)             (None, 35, 35, 192)  331968      concatenate_17[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 35, 35, 192)  0           concatenate_17[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 35, 35, 384)  0           conv2d_129[0][0]
#                                                                  max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_130 (Conv2D)             (None, 35, 35, 64)   24640       concatenate_18[0][0]
# __________________________________________________________________________________________________
# conv2d_133 (Conv2D)             (None, 35, 35, 96)   55392       conv2d_130[0][0]
# __________________________________________________________________________________________________
# conv2d_131 (Conv2D)             (None, 35, 35, 64)   24640       concatenate_18[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_11 (AveragePo (None, 35, 35, 384)  0           concatenate_18[0][0]
# __________________________________________________________________________________________________
# conv2d_136 (Conv2D)             (None, 35, 35, 96)   83040       conv2d_133[0][0]
# __________________________________________________________________________________________________
# conv2d_134 (Conv2D)             (None, 35, 35, 96)   55392       conv2d_131[0][0]
# __________________________________________________________________________________________________
# conv2d_132 (Conv2D)             (None, 35, 35, 96)   36960       concatenate_18[0][0]
# __________________________________________________________________________________________________
# conv2d_135 (Conv2D)             (None, 35, 35, 96)   36960       average_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 35, 35, 384)  0           conv2d_136[0][0]
#                                                                  conv2d_134[0][0]
#                                                                  conv2d_132[0][0]
#                                                                  conv2d_135[0][0]
# __________________________________________________________________________________________________
# conv2d_137 (Conv2D)             (None, 35, 35, 64)   24640       concatenate_19[0][0]
# __________________________________________________________________________________________________
# conv2d_140 (Conv2D)             (None, 35, 35, 96)   55392       conv2d_137[0][0]
# __________________________________________________________________________________________________
# conv2d_138 (Conv2D)             (None, 35, 35, 64)   24640       concatenate_19[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_12 (AveragePo (None, 35, 35, 384)  0           concatenate_19[0][0]
# __________________________________________________________________________________________________
# conv2d_143 (Conv2D)             (None, 35, 35, 96)   83040       conv2d_140[0][0]
# __________________________________________________________________________________________________
# conv2d_141 (Conv2D)             (None, 35, 35, 96)   55392       conv2d_138[0][0]
# __________________________________________________________________________________________________
# conv2d_139 (Conv2D)             (None, 35, 35, 96)   36960       concatenate_19[0][0]
# __________________________________________________________________________________________________
# conv2d_142 (Conv2D)             (None, 35, 35, 96)   36960       average_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 35, 35, 384)  0           conv2d_143[0][0]
#                                                                  conv2d_141[0][0]
#                                                                  conv2d_139[0][0]
#                                                                  conv2d_142[0][0]
# __________________________________________________________________________________________________
# conv2d_144 (Conv2D)             (None, 35, 35, 64)   24640       concatenate_20[0][0]
# __________________________________________________________________________________________________
# conv2d_147 (Conv2D)             (None, 35, 35, 96)   55392       conv2d_144[0][0]
# __________________________________________________________________________________________________
# conv2d_145 (Conv2D)             (None, 35, 35, 64)   24640       concatenate_20[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_13 (AveragePo (None, 35, 35, 384)  0           concatenate_20[0][0]
# __________________________________________________________________________________________________
# conv2d_150 (Conv2D)             (None, 35, 35, 96)   83040       conv2d_147[0][0]
# __________________________________________________________________________________________________
# conv2d_148 (Conv2D)             (None, 35, 35, 96)   55392       conv2d_145[0][0]
# __________________________________________________________________________________________________
# conv2d_146 (Conv2D)             (None, 35, 35, 96)   36960       concatenate_20[0][0]
# __________________________________________________________________________________________________
# conv2d_149 (Conv2D)             (None, 35, 35, 96)   36960       average_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 35, 35, 384)  0           conv2d_150[0][0]
#                                                                  conv2d_148[0][0]
#                                                                  conv2d_146[0][0]
#                                                                  conv2d_149[0][0]
# __________________________________________________________________________________________________
# conv2d_151 (Conv2D)             (None, 35, 35, 64)   24640       concatenate_21[0][0]
# __________________________________________________________________________________________________
# conv2d_154 (Conv2D)             (None, 35, 35, 96)   55392       conv2d_151[0][0]
# __________________________________________________________________________________________________
# conv2d_152 (Conv2D)             (None, 35, 35, 64)   24640       concatenate_21[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_14 (AveragePo (None, 35, 35, 384)  0           concatenate_21[0][0]
# __________________________________________________________________________________________________
# conv2d_157 (Conv2D)             (None, 35, 35, 96)   83040       conv2d_154[0][0]
# __________________________________________________________________________________________________
# conv2d_155 (Conv2D)             (None, 35, 35, 96)   55392       conv2d_152[0][0]
# __________________________________________________________________________________________________
# conv2d_153 (Conv2D)             (None, 35, 35, 96)   36960       concatenate_21[0][0]
# __________________________________________________________________________________________________
# conv2d_156 (Conv2D)             (None, 35, 35, 96)   36960       average_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 35, 35, 384)  0           conv2d_157[0][0]
#                                                                  conv2d_155[0][0]
#                                                                  conv2d_153[0][0]
#                                                                  conv2d_156[0][0]
# __________________________________________________________________________________________________
# conv2d_158 (Conv2D)             (None, 35, 35, 192)  73920       concatenate_22[0][0]
# __________________________________________________________________________________________________
# conv2d_159 (Conv2D)             (None, 35, 35, 224)  387296      conv2d_158[0][0]
# __________________________________________________________________________________________________
# conv2d_161 (Conv2D)             (None, 17, 17, 256)  516352      conv2d_159[0][0]
# __________________________________________________________________________________________________
# conv2d_160 (Conv2D)             (None, 17, 17, 384)  1327488     concatenate_22[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 17, 17, 384)  0           concatenate_22[0][0]
# __________________________________________________________________________________________________
# concatenate_23 (Concatenate)    (None, 17, 17, 1024) 0           conv2d_161[0][0]
#                                                                  conv2d_160[0][0]
#                                                                  max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 17, 17, 1024) 4096        concatenate_23[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 8, 8, 1024)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_162 (Conv2D)             (None, 8, 8, 192)    196800      max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_163 (Conv2D)             (None, 8, 8, 192)    258240      conv2d_162[0][0]
# __________________________________________________________________________________________________
# conv2d_164 (Conv2D)             (None, 8, 8, 224)    301280      conv2d_163[0][0]
# __________________________________________________________________________________________________
# conv2d_167 (Conv2D)             (None, 8, 8, 192)    196800      max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_165 (Conv2D)             (None, 8, 8, 224)    351456      conv2d_164[0][0]
# __________________________________________________________________________________________________
# conv2d_168 (Conv2D)             (None, 8, 8, 224)    301280      conv2d_167[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_15 (AveragePo (None, 8, 8, 1024)   0           max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_166 (Conv2D)             (None, 8, 8, 256)    401664      conv2d_165[0][0]
# __________________________________________________________________________________________________
# conv2d_169 (Conv2D)             (None, 8, 8, 256)    401664      conv2d_168[0][0]
# __________________________________________________________________________________________________
# conv2d_170 (Conv2D)             (None, 8, 8, 128)    131200      average_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_171 (Conv2D)             (None, 8, 8, 384)    393600      max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate_24 (Concatenate)    (None, 8, 8, 1024)   0           conv2d_166[0][0]
#                                                                  conv2d_169[0][0]
#                                                                  conv2d_170[0][0]
#                                                                  conv2d_171[0][0]
# __________________________________________________________________________________________________
# conv2d_172 (Conv2D)             (None, 8, 8, 192)    196800      concatenate_24[0][0]
# __________________________________________________________________________________________________
# conv2d_173 (Conv2D)             (None, 8, 8, 192)    258240      conv2d_172[0][0]
# __________________________________________________________________________________________________
# conv2d_174 (Conv2D)             (None, 8, 8, 224)    301280      conv2d_173[0][0]
# __________________________________________________________________________________________________
# conv2d_177 (Conv2D)             (None, 8, 8, 192)    196800      concatenate_24[0][0]
# __________________________________________________________________________________________________
# conv2d_175 (Conv2D)             (None, 8, 8, 224)    351456      conv2d_174[0][0]
# __________________________________________________________________________________________________
# conv2d_178 (Conv2D)             (None, 8, 8, 224)    301280      conv2d_177[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_16 (AveragePo (None, 8, 8, 1024)   0           concatenate_24[0][0]
# __________________________________________________________________________________________________
# conv2d_176 (Conv2D)             (None, 8, 8, 256)    401664      conv2d_175[0][0]
# __________________________________________________________________________________________________
# conv2d_179 (Conv2D)             (None, 8, 8, 256)    401664      conv2d_178[0][0]
# __________________________________________________________________________________________________
# conv2d_180 (Conv2D)             (None, 8, 8, 128)    131200      average_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_181 (Conv2D)             (None, 8, 8, 384)    393600      concatenate_24[0][0]
# __________________________________________________________________________________________________
# concatenate_25 (Concatenate)    (None, 8, 8, 1024)   0           conv2d_176[0][0]
#                                                                  conv2d_179[0][0]
#                                                                  conv2d_180[0][0]
#                                                                  conv2d_181[0][0]
# __________________________________________________________________________________________________
# conv2d_182 (Conv2D)             (None, 8, 8, 192)    196800      concatenate_25[0][0]
# __________________________________________________________________________________________________
# conv2d_183 (Conv2D)             (None, 8, 8, 192)    258240      conv2d_182[0][0]
# __________________________________________________________________________________________________
# conv2d_184 (Conv2D)             (None, 8, 8, 224)    301280      conv2d_183[0][0]
# __________________________________________________________________________________________________
# conv2d_187 (Conv2D)             (None, 8, 8, 192)    196800      concatenate_25[0][0]
# __________________________________________________________________________________________________
# conv2d_185 (Conv2D)             (None, 8, 8, 224)    351456      conv2d_184[0][0]
# __________________________________________________________________________________________________
# conv2d_188 (Conv2D)             (None, 8, 8, 224)    301280      conv2d_187[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_17 (AveragePo (None, 8, 8, 1024)   0           concatenate_25[0][0]
# __________________________________________________________________________________________________
# conv2d_186 (Conv2D)             (None, 8, 8, 256)    401664      conv2d_185[0][0]
# __________________________________________________________________________________________________
# conv2d_189 (Conv2D)             (None, 8, 8, 256)    401664      conv2d_188[0][0]
# __________________________________________________________________________________________________
# conv2d_190 (Conv2D)             (None, 8, 8, 128)    131200      average_pooling2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_191 (Conv2D)             (None, 8, 8, 384)    393600      concatenate_25[0][0]
# __________________________________________________________________________________________________
# concatenate_26 (Concatenate)    (None, 8, 8, 1024)   0           conv2d_186[0][0]
#                                                                  conv2d_189[0][0]
#                                                                  conv2d_190[0][0]
#                                                                  conv2d_191[0][0]
# __________________________________________________________________________________________________
# conv2d_192 (Conv2D)             (None, 8, 8, 192)    196800      concatenate_26[0][0]
# __________________________________________________________________________________________________
# conv2d_193 (Conv2D)             (None, 8, 8, 192)    258240      conv2d_192[0][0]
# __________________________________________________________________________________________________
# conv2d_194 (Conv2D)             (None, 8, 8, 224)    301280      conv2d_193[0][0]
# __________________________________________________________________________________________________
# conv2d_197 (Conv2D)             (None, 8, 8, 192)    196800      concatenate_26[0][0]
# __________________________________________________________________________________________________
# conv2d_195 (Conv2D)             (None, 8, 8, 224)    351456      conv2d_194[0][0]
# __________________________________________________________________________________________________
# conv2d_198 (Conv2D)             (None, 8, 8, 224)    301280      conv2d_197[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_18 (AveragePo (None, 8, 8, 1024)   0           concatenate_26[0][0]
# __________________________________________________________________________________________________
# conv2d_196 (Conv2D)             (None, 8, 8, 256)    401664      conv2d_195[0][0]
# __________________________________________________________________________________________________
# conv2d_199 (Conv2D)             (None, 8, 8, 256)    401664      conv2d_198[0][0]
# __________________________________________________________________________________________________
# conv2d_200 (Conv2D)             (None, 8, 8, 128)    131200      average_pooling2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_201 (Conv2D)             (None, 8, 8, 384)    393600      concatenate_26[0][0]
# __________________________________________________________________________________________________
# concatenate_27 (Concatenate)    (None, 8, 8, 1024)   0           conv2d_196[0][0]
#                                                                  conv2d_199[0][0]
#                                                                  conv2d_200[0][0]
#                                                                  conv2d_201[0][0]
# __________________________________________________________________________________________________
# conv2d_202 (Conv2D)             (None, 8, 8, 192)    196800      concatenate_27[0][0]
# __________________________________________________________________________________________________
# conv2d_203 (Conv2D)             (None, 8, 8, 192)    258240      conv2d_202[0][0]
# __________________________________________________________________________________________________
# conv2d_204 (Conv2D)             (None, 8, 8, 224)    301280      conv2d_203[0][0]
# __________________________________________________________________________________________________
# conv2d_207 (Conv2D)             (None, 8, 8, 192)    196800      concatenate_27[0][0]
# __________________________________________________________________________________________________
# conv2d_205 (Conv2D)             (None, 8, 8, 224)    351456      conv2d_204[0][0]
# __________________________________________________________________________________________________
# conv2d_208 (Conv2D)             (None, 8, 8, 224)    301280      conv2d_207[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_19 (AveragePo (None, 8, 8, 1024)   0           concatenate_27[0][0]
# __________________________________________________________________________________________________
# conv2d_206 (Conv2D)             (None, 8, 8, 256)    401664      conv2d_205[0][0]
# __________________________________________________________________________________________________
# conv2d_209 (Conv2D)             (None, 8, 8, 256)    401664      conv2d_208[0][0]
# __________________________________________________________________________________________________
# conv2d_210 (Conv2D)             (None, 8, 8, 128)    131200      average_pooling2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_211 (Conv2D)             (None, 8, 8, 384)    393600      concatenate_27[0][0]
# __________________________________________________________________________________________________
# concatenate_28 (Concatenate)    (None, 8, 8, 1024)   0           conv2d_206[0][0]
#                                                                  conv2d_209[0][0]
#                                                                  conv2d_210[0][0]
#                                                                  conv2d_211[0][0]
# __________________________________________________________________________________________________
# conv2d_212 (Conv2D)             (None, 8, 8, 192)    196800      concatenate_28[0][0]
# __________________________________________________________________________________________________
# conv2d_213 (Conv2D)             (None, 8, 8, 192)    258240      conv2d_212[0][0]
# __________________________________________________________________________________________________
# conv2d_214 (Conv2D)             (None, 8, 8, 224)    301280      conv2d_213[0][0]
# __________________________________________________________________________________________________
# conv2d_217 (Conv2D)             (None, 8, 8, 192)    196800      concatenate_28[0][0]
# __________________________________________________________________________________________________
# conv2d_215 (Conv2D)             (None, 8, 8, 224)    351456      conv2d_214[0][0]
# __________________________________________________________________________________________________
# conv2d_218 (Conv2D)             (None, 8, 8, 224)    301280      conv2d_217[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_20 (AveragePo (None, 8, 8, 1024)   0           concatenate_28[0][0]
# __________________________________________________________________________________________________
# conv2d_216 (Conv2D)             (None, 8, 8, 256)    401664      conv2d_215[0][0]
# __________________________________________________________________________________________________
# conv2d_219 (Conv2D)             (None, 8, 8, 256)    401664      conv2d_218[0][0]
# __________________________________________________________________________________________________
# conv2d_220 (Conv2D)             (None, 8, 8, 128)    131200      average_pooling2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_221 (Conv2D)             (None, 8, 8, 384)    393600      concatenate_28[0][0]
# __________________________________________________________________________________________________
# concatenate_29 (Concatenate)    (None, 8, 8, 1024)   0           conv2d_216[0][0]
#                                                                  conv2d_219[0][0]
#                                                                  conv2d_220[0][0]
#                                                                  conv2d_221[0][0]
# __________________________________________________________________________________________________
# conv2d_222 (Conv2D)             (None, 8, 8, 192)    196800      concatenate_29[0][0]
# __________________________________________________________________________________________________
# conv2d_223 (Conv2D)             (None, 8, 8, 192)    258240      conv2d_222[0][0]
# __________________________________________________________________________________________________
# conv2d_224 (Conv2D)             (None, 8, 8, 224)    301280      conv2d_223[0][0]
# __________________________________________________________________________________________________
# conv2d_227 (Conv2D)             (None, 8, 8, 192)    196800      concatenate_29[0][0]
# __________________________________________________________________________________________________
# conv2d_225 (Conv2D)             (None, 8, 8, 224)    351456      conv2d_224[0][0]
# __________________________________________________________________________________________________
# conv2d_228 (Conv2D)             (None, 8, 8, 224)    301280      conv2d_227[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_21 (AveragePo (None, 8, 8, 1024)   0           concatenate_29[0][0]
# __________________________________________________________________________________________________
# conv2d_226 (Conv2D)             (None, 8, 8, 256)    401664      conv2d_225[0][0]
# __________________________________________________________________________________________________
# conv2d_229 (Conv2D)             (None, 8, 8, 256)    401664      conv2d_228[0][0]
# __________________________________________________________________________________________________
# conv2d_230 (Conv2D)             (None, 8, 8, 128)    131200      average_pooling2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_231 (Conv2D)             (None, 8, 8, 384)    393600      concatenate_29[0][0]
# __________________________________________________________________________________________________
# concatenate_30 (Concatenate)    (None, 8, 8, 1024)   0           conv2d_226[0][0]
#                                                                  conv2d_229[0][0]
#                                                                  conv2d_230[0][0]
#                                                                  conv2d_231[0][0]
# __________________________________________________________________________________________________
# conv2d_232 (Conv2D)             (None, 8, 8, 256)    262400      concatenate_30[0][0]
# __________________________________________________________________________________________________
# conv2d_233 (Conv2D)             (None, 8, 8, 256)    459008      conv2d_232[0][0]
# __________________________________________________________________________________________________
# conv2d_234 (Conv2D)             (None, 8, 8, 320)    573760      conv2d_233[0][0]
# __________________________________________________________________________________________________
# conv2d_236 (Conv2D)             (None, 8, 8, 192)    196800      concatenate_30[0][0]
# __________________________________________________________________________________________________
# conv2d_235 (Conv2D)             (None, 3, 3, 320)    921920      conv2d_234[0][0]
# __________________________________________________________________________________________________
# conv2d_237 (Conv2D)             (None, 3, 3, 192)    331968      conv2d_236[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 3, 3, 1024)   0           concatenate_30[0][0]
# __________________________________________________________________________________________________
# concatenate_31 (Concatenate)    (None, 3, 3, 1536)   0           conv2d_235[0][0]
#                                                                  conv2d_237[0][0]
#                                                                  max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 3, 3, 1536)   6144        concatenate_31[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 1, 1, 1536)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_238 (Conv2D)             (None, 1, 1, 384)    590208      max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_239 (Conv2D)             (None, 1, 1, 448)    516544      conv2d_238[0][0]
# __________________________________________________________________________________________________
# conv2d_240 (Conv2D)             (None, 1, 1, 512)    688640      conv2d_239[0][0]
# __________________________________________________________________________________________________
# conv2d_243 (Conv2D)             (None, 1, 1, 384)    590208      max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_22 (AveragePo (None, 1, 1, 1536)   0           max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_242 (Conv2D)             (None, 1, 1, 256)    393472      conv2d_240[0][0]
# __________________________________________________________________________________________________
# conv2d_241 (Conv2D)             (None, 1, 1, 256)    393472      conv2d_240[0][0]
# __________________________________________________________________________________________________
# conv2d_244 (Conv2D)             (None, 1, 1, 256)    295168      conv2d_243[0][0]
# __________________________________________________________________________________________________
# conv2d_245 (Conv2D)             (None, 1, 1, 256)    295168      conv2d_243[0][0]
# __________________________________________________________________________________________________
# conv2d_247 (Conv2D)             (None, 1, 1, 256)    393472      max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_246 (Conv2D)             (None, 1, 1, 256)    393472      average_pooling2d_22[0][0]
# __________________________________________________________________________________________________
# concatenate_32 (Concatenate)    (None, 1, 1, 1536)   0           conv2d_242[0][0]
#                                                                  conv2d_241[0][0]
#                                                                  conv2d_244[0][0]
#                                                                  conv2d_245[0][0]
#                                                                  conv2d_247[0][0]
#                                                                  conv2d_246[0][0]
# __________________________________________________________________________________________________
# conv2d_248 (Conv2D)             (None, 1, 1, 384)    590208      concatenate_32[0][0]
# __________________________________________________________________________________________________
# conv2d_249 (Conv2D)             (None, 1, 1, 448)    516544      conv2d_248[0][0]
# __________________________________________________________________________________________________
# conv2d_250 (Conv2D)             (None, 1, 1, 512)    688640      conv2d_249[0][0]
# __________________________________________________________________________________________________
# conv2d_253 (Conv2D)             (None, 1, 1, 384)    590208      concatenate_32[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_23 (AveragePo (None, 1, 1, 1536)   0           concatenate_32[0][0]
# __________________________________________________________________________________________________
# conv2d_252 (Conv2D)             (None, 1, 1, 256)    393472      conv2d_250[0][0]
# __________________________________________________________________________________________________
# conv2d_251 (Conv2D)             (None, 1, 1, 256)    393472      conv2d_250[0][0]
# __________________________________________________________________________________________________
# conv2d_254 (Conv2D)             (None, 1, 1, 256)    295168      conv2d_253[0][0]
# __________________________________________________________________________________________________
# conv2d_255 (Conv2D)             (None, 1, 1, 256)    295168      conv2d_253[0][0]
# __________________________________________________________________________________________________
# conv2d_257 (Conv2D)             (None, 1, 1, 256)    393472      concatenate_32[0][0]
# __________________________________________________________________________________________________
# conv2d_256 (Conv2D)             (None, 1, 1, 256)    393472      average_pooling2d_23[0][0]
# __________________________________________________________________________________________________
# concatenate_33 (Concatenate)    (None, 1, 1, 1536)   0           conv2d_252[0][0]
#                                                                  conv2d_251[0][0]
#                                                                  conv2d_254[0][0]
#                                                                  conv2d_255[0][0]
#                                                                  conv2d_257[0][0]
#                                                                  conv2d_256[0][0]
# __________________________________________________________________________________________________
# conv2d_258 (Conv2D)             (None, 1, 1, 384)    590208      concatenate_33[0][0]
# __________________________________________________________________________________________________
# conv2d_259 (Conv2D)             (None, 1, 1, 448)    516544      conv2d_258[0][0]
# __________________________________________________________________________________________________
# conv2d_260 (Conv2D)             (None, 1, 1, 512)    688640      conv2d_259[0][0]
# __________________________________________________________________________________________________
# conv2d_263 (Conv2D)             (None, 1, 1, 384)    590208      concatenate_33[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_24 (AveragePo (None, 1, 1, 1536)   0           concatenate_33[0][0]
# __________________________________________________________________________________________________
# conv2d_262 (Conv2D)             (None, 1, 1, 256)    393472      conv2d_260[0][0]
# __________________________________________________________________________________________________
# conv2d_261 (Conv2D)             (None, 1, 1, 256)    393472      conv2d_260[0][0]
# __________________________________________________________________________________________________
# conv2d_264 (Conv2D)             (None, 1, 1, 256)    295168      conv2d_263[0][0]
# __________________________________________________________________________________________________
# conv2d_265 (Conv2D)             (None, 1, 1, 256)    295168      conv2d_263[0][0]
# __________________________________________________________________________________________________
# conv2d_267 (Conv2D)             (None, 1, 1, 256)    393472      concatenate_33[0][0]
# __________________________________________________________________________________________________
# conv2d_266 (Conv2D)             (None, 1, 1, 256)    393472      average_pooling2d_24[0][0]
# __________________________________________________________________________________________________
# concatenate_34 (Concatenate)    (None, 1, 1, 1536)   0           conv2d_262[0][0]
#                                                                  conv2d_261[0][0]
#                                                                  conv2d_264[0][0]
#                                                                  conv2d_265[0][0]
#                                                                  conv2d_267[0][0]
#                                                                  conv2d_266[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 1, 1, 1536)   6144        concatenate_34[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 1536)         0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 2048)         3147776     global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 2048)         0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            2049        dropout[0][0]
# ==================================================================================================
# Total params: 44,267,137
# Trainable params: 44,258,945
# Non-trainable params: 8,192
# __________________________________________________________________________________________________

# %% [markdown]
# ## Acoplamiento de los datos

# %%
input_dir= "/home/revientaelp/Documentos/Bases de datos/Sharon/patch_m300/entA"
target_dir= "/home/revientaelp/Documentos/Bases de datos/Sharon/patch_m300/valA"

generador_ent= ImageDataGenerator(rescale= 1/255.0)
generador_val= ImageDataGenerator(rescale= 1/255.0)


ent_gen= generador_ent.flow_from_directory(input_dir, 
                                           target_size=(300, 300),
                                           class_mode= 'binary',
                                           batch_size= 16,
                                           color_mode= "rgb",
                                           shuffle= True,
                                           )

val_gen= generador_val.flow_from_directory(target_dir, 
                                           target_size=(300, 300),
                                           class_mode= 'binary',
                                           color_mode= "rgb",
                                           batch_size= 16,
                                           shuffle= True,
                                           )
# Out:
# Found 15954 images belonging to 2 classes.
# Found 1194 images belonging to 2 classes.

# %%
def entrenamient_modelo(train_gen, val_gen, DIR_save, epocas= 30):

    #class_weights = {0:1., 1:1.5, 2:1.5, 3:4, 4:4}

    #Generamos los callback necesarios
    checkpoint= ModelCheckpoint(DIR_save+ "01092021_A1.hdf5", monitor= 'val_loss', save_best_only= True, mode= 'min', save_weights_only= False)
    #reduceLROnPlat= ReduceLROnPlateau(monitor= 'val_loss', factor= 0.8, patience= 15, min_delta= 0.001, cooldown= 10, min_lr= 0.00001)
    #tensorboard_callback = TensorBoard()#log_dir= datetime.now().strftime("%Y%m%d-%H%M%S"))
    callbacks= [EarlyStopping(patience= 30,  monitor='val_loss'), checkpoint]#, tensorboard_callback]
    metrica= [tf.keras.metrics.AUC(),
              tf.keras.metrics.BinaryAccuracy(),
              tf.keras.metrics.Recall(),
              tf.keras.metrics.Precision()]

    #Compilamos con la funcion perdida y el optimizador que utilizaremos
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate= 0.00001), loss = 'binary_crossentropy', metrics= metrica)
    history= model.fit(train_gen, batch_size= 16, epochs=epocas, validation_data=val_gen, callbacks=callbacks)

def carga_mod(DIR):
    return tf.keras.models.load_model(DIR)

# %%
DIR_save_best= '/home/revientaelp/Escritorio/'
#DIR_save_best= '/content/drive/MyDrive/Modelos guardados/Exudados_SGD/'
#DIR_load_best= '/content/drive/MyDrive/Modelos guardados/Clasificacion_exudados_SGD_IV4/06082021_400.hdf5'

#model= carga_mod(DIR_load_best)
entrenamient_modelo(ent_gen, val_gen, DIR_save_best, 400)
# Out:
# Epoch 1/400
# 998/998 [==============================] - 399s 400ms/step - loss: 0.3906 - auc: 0.8733 - binary_accuracy: 0.8320 - recall: 0.8926 - precision: 0.8595 - val_loss: 0.3505 - val_auc: 0.5946 - val_binary_accuracy: 0.8819 - val_recall: 0.9915 - val_precision: 0.8880
# Epoch 2/400
# 998/998 [==============================] - 304s 305ms/step - loss: 0.3068 - auc: 0.9046 - binary_accuracy: 0.8865 - recall: 0.9628 - precision: 0.8778 - val_loss: 0.3690 - val_auc: 0.6235 - val_binary_accuracy: 0.8693 - val_recall: 0.9574 - val_precision: 0.9011
# Epoch 3/400
# 998/998 [==============================] - 310s 310ms/step - loss: 0.2957 - auc: 0.9088 - binary_accuracy: 0.8936 - recall: 0.9682 - precision: 0.8827 - val_loss: 0.3851 - val_auc: 0.5336 - val_binary_accuracy: 0.8719 - val_recall: 0.9858 - val_precision: 0.8830
# Epoch 4/400
# 998/998 [==============================] - 309s 310ms/step - loss: 0.2872 - auc: 0.9138 - binary_accuracy: 0.8990 - recall: 0.9743 - precision: 0.8850 - val_loss: 0.5013 - val_auc: 0.5726 - val_binary_accuracy: 0.8124 - val_recall: 0.8797 - val_precision: 0.9055
# Epoch 5/400
# 998/998 [==============================] - 310s 310ms/step - loss: 0.2809 - auc: 0.9175 - binary_accuracy: 0.9016 - recall: 0.9734 - precision: 0.8887 - val_loss: 0.5428 - val_auc: 0.6117 - val_binary_accuracy: 0.8844 - val_recall: 1.0000 - val_precision: 0.8844
# Epoch 6/400
# 998/998 [==============================] - 310s 311ms/step - loss: 0.2759 - auc: 0.9180 - binary_accuracy: 0.9032 - recall: 0.9762 - precision: 0.8888 - val_loss: 1.5390 - val_auc: 0.6068 - val_binary_accuracy: 0.2621 - val_recall: 0.1809 - val_precision: 0.9227
# Epoch 7/400
# 998/998 [==============================] - 309s 310ms/step - loss: 0.2718 - auc: 0.9243 - binary_accuracy: 0.9025 - recall: 0.9732 - precision: 0.8900 - val_loss: 0.4706 - val_auc: 0.5572 - val_binary_accuracy: 0.8291 - val_recall: 0.8996 - val_precision: 0.9065
# Epoch 8/400
# 998/998 [==============================] - 309s 310ms/step - loss: 0.2626 - auc: 0.9283 - binary_accuracy: 0.9067 - recall: 0.9775 - precision: 0.8921 - val_loss: 0.9283 - val_auc: 0.6099 - val_binary_accuracy: 0.5561 - val_recall: 0.5549 - val_precision: 0.9071
# Epoch 9/400
# 998/998 [==============================] - 307s 308ms/step - loss: 0.2556 - auc: 0.9343 - binary_accuracy: 0.9074 - recall: 0.9740 - precision: 0.8954 - val_loss: 0.5488 - val_auc: 0.5900 - val_binary_accuracy: 0.8844 - val_recall: 0.9943 - val_precision: 0.8883
# Epoch 10/400
# 998/998 [==============================] - 309s 309ms/step - loss: 0.2466 - auc: 0.9386 - binary_accuracy: 0.9112 - recall: 0.9760 - precision: 0.8988 - val_loss: 0.3977 - val_auc: 0.6499 - val_binary_accuracy: 0.8978 - val_recall: 0.9943 - val_precision: 0.9005
# Epoch 11/400
# 998/998 [==============================] - 310s 310ms/step - loss: 0.2408 - auc: 0.9423 - binary_accuracy: 0.9121 - recall: 0.9763 - precision: 0.8997 - val_loss: 0.3611 - val_auc: 0.6570 - val_binary_accuracy: 0.8920 - val_recall: 0.9830 - val_precision: 0.9034
# Epoch 12/400
# 998/998 [==============================] - 310s 310ms/step - loss: 0.2301 - auc: 0.9489 - binary_accuracy: 0.9138 - recall: 0.9735 - precision: 0.9039 - val_loss: 0.3741 - val_auc: 0.7419 - val_binary_accuracy: 0.8610 - val_recall: 0.9394 - val_precision: 0.9068
# Epoch 13/400
# 998/998 [==============================] - 309s 310ms/step - loss: 0.2216 - auc: 0.9539 - binary_accuracy: 0.9155 - recall: 0.9697 - precision: 0.9089 - val_loss: 0.6993 - val_auc: 0.6267 - val_binary_accuracy: 0.7270 - val_recall: 0.7633 - val_precision: 0.9138
# Epoch 14/400
# 998/998 [==============================] - 309s 310ms/step - loss: 0.2100 - auc: 0.9584 - binary_accuracy: 0.9206 - recall: 0.9732 - precision: 0.9129 - val_loss: 0.4475 - val_auc: 0.7561 - val_binary_accuracy: 0.8023 - val_recall: 0.8608 - val_precision: 0.9108
# Epoch 15/400
# 998/998 [==============================] - 309s 309ms/step - loss: 0.1950 - auc: 0.9655 - binary_accuracy: 0.9276 - recall: 0.9721 - precision: 0.9228 - val_loss: 0.4597 - val_auc: 0.6130 - val_binary_accuracy: 0.8392 - val_recall: 0.9328 - val_precision: 0.8906
# Epoch 16/400
# 998/998 [==============================] - 310s 311ms/step - loss: 0.1846 - auc: 0.9696 - binary_accuracy: 0.9285 - recall: 0.9711 - precision: 0.9248 - val_loss: 0.4829 - val_auc: 0.6828 - val_binary_accuracy: 0.7797 - val_recall: 0.8438 - val_precision: 0.9009
# Epoch 17/400
# 998/998 [==============================] - 310s 310ms/step - loss: 0.1733 - auc: 0.9741 - binary_accuracy: 0.9328 - recall: 0.9691 - precision: 0.9322 - val_loss: 0.5092 - val_auc: 0.6580 - val_binary_accuracy: 0.7764 - val_recall: 0.8381 - val_precision: 0.9021
# Epoch 18/400
# 998/998 [==============================] - 310s 310ms/step - loss: 0.1539 - auc: 0.9798 - binary_accuracy: 0.9405 - recall: 0.9700 - precision: 0.9419 - val_loss: 0.3779 - val_auc: 0.7351 - val_binary_accuracy: 0.8819 - val_recall: 0.9735 - val_precision: 0.9010
# Epoch 19/400
# 998/998 [==============================] - 310s 310ms/step - loss: 0.1405 - auc: 0.9833 - binary_accuracy: 0.9458 - recall: 0.9726 - precision: 0.9471 - val_loss: 0.5012 - val_auc: 0.7294 - val_binary_accuracy: 0.8032 - val_recall: 0.8570 - val_precision: 0.9151
# Epoch 20/400
# 998/998 [==============================] - 309s 310ms/step - loss: 0.1299 - auc: 0.9861 - binary_accuracy: 0.9505 - recall: 0.9737 - precision: 0.9527 - val_loss: 0.5423 - val_auc: 0.6737 - val_binary_accuracy: 0.8760 - val_recall: 0.9716 - val_precision: 0.8969
# Epoch 21/400
# 998/998 [==============================] - 310s 310ms/step - loss: 0.1119 - auc: 0.9895 - binary_accuracy: 0.9581 - recall: 0.9775 - precision: 0.9600 - val_loss: 0.5037 - val_auc: 0.6954 - val_binary_accuracy: 0.8451 - val_recall: 0.9299 - val_precision: 0.8984
# Epoch 22/400
# 998/998 [==============================] - 309s 310ms/step - loss: 0.1037 - auc: 0.9909 - binary_accuracy: 0.9624 - recall: 0.9778 - precision: 0.9659 - val_loss: 0.5195 - val_auc: 0.6807 - val_binary_accuracy: 0.8777 - val_recall: 0.9735 - val_precision: 0.8970
# Epoch 23/400
# 998/998 [==============================] - 310s 310ms/step - loss: 0.0999 - auc: 0.9913 - binary_accuracy: 0.9630 - recall: 0.9787 - precision: 0.9659 - val_loss: 0.5951 - val_auc: 0.6851 - val_binary_accuracy: 0.8819 - val_recall: 0.9801 - val_precision: 0.8961
# Epoch 24/400
# 998/998 [==============================] - 309s 310ms/step - loss: 0.0866 - auc: 0.9938 - binary_accuracy: 0.9678 - recall: 0.9802 - precision: 0.9714 - val_loss: 0.7389 - val_auc: 0.6477 - val_binary_accuracy: 0.8534 - val_recall: 0.9470 - val_precision: 0.8937
# Epoch 25/400
# 998/998 [==============================] - 310s 310ms/step - loss: 0.0756 - auc: 0.9944 - binary_accuracy: 0.9733 - recall: 0.9837 - precision: 0.9762 - val_loss: 0.7165 - val_auc: 0.7277 - val_binary_accuracy: 0.7672 - val_recall: 0.8049 - val_precision: 0.9219
# Epoch 26/400
# 998/998 [==============================] - 309s 310ms/step - loss: 0.0812 - auc: 0.9939 - binary_accuracy: 0.9705 - recall: 0.9828 - precision: 0.9730 - val_loss: 0.6881 - val_auc: 0.6910 - val_binary_accuracy: 0.7688 - val_recall: 0.8220 - val_precision: 0.9079
# Epoch 27/400
# 998/998 [==============================] - 309s 310ms/step - loss: 0.0751 - auc: 0.9950 - binary_accuracy: 0.9719 - recall: 0.9817 - precision: 0.9761 - val_loss: 0.6405 - val_auc: 0.6687 - val_binary_accuracy: 0.7797 - val_recall: 0.8561 - val_precision: 0.8906
# Epoch 28/400
# 998/998 [==============================] - 309s 310ms/step - loss: 0.0604 - auc: 0.9971 - binary_accuracy: 0.9781 - recall: 0.9865 - precision: 0.9806 - val_loss: 1.1818 - val_auc: 0.7417 - val_binary_accuracy: 0.6508 - val_recall: 0.6402 - val_precision: 0.9481
# Epoch 29/400
# 998/998 [==============================] - 310s 310ms/step - loss: 0.0615 - auc: 0.9965 - binary_accuracy: 0.9779 - recall: 0.9855 - precision: 0.9813 - val_loss: 0.7127 - val_auc: 0.6898 - val_binary_accuracy: 0.8518 - val_recall: 0.9309 - val_precision: 0.9043
# Epoch 30/400
# 998/998 [==============================] - 309s 310ms/step - loss: 0.0612 - auc: 0.9964 - binary_accuracy: 0.9772 - recall: 0.9853 - precision: 0.9804 - val_loss: 0.8496 - val_auc: 0.5814 - val_binary_accuracy: 0.8844 - val_recall: 0.9905 - val_precision: 0.8910
# Epoch 31/400
# 998/998 [==============================] - 309s 310ms/step - loss: 0.0613 - auc: 0.9968 - binary_accuracy: 0.9777 - recall: 0.9853 - precision: 0.9812 - val_loss: 0.6148 - val_auc: 0.7291 - val_binary_accuracy: 0.8375 - val_recall: 0.9072 - val_precision: 0.9089
